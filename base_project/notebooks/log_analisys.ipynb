# %%
import os
import sys
import pandas as pd
sys.path.append(os.pardir)
from settings import LOG_DIR

# %%
fp = os.path.join(LOG_DIR, "error.log")
log_df = pd.read_csv(fp, header=None, delimiter="|")
log_df.columns = [
    "datetime",
    "level",
    "name",
    "module",
    "lineno",
    "funcName",
    "error",
    "traceback1",
    "traceback2",
    "traceback3",
    "traceback4",
]
log_df
log_df.head()
# Out:
#                   datetime  level      name    module  lineno  funcName  \
# 0  2022-01-09 17:42:45,018  ERROR  __main__  __main__      32  <module>
# 1  2022-01-09 17:42:45,019  ERROR  __main__  __main__      38  <module>
# 2  2022-01-09 17:49:26,959  ERROR  __main__  __main__      27  <module>
# 3  2022-01-09 17:49:26,960  ERROR  __main__  __main__      33  <module>
#
#                                               error  \
# 0                                  division by zero
# 1  invalid literal for int() with base 10: 'animal'
# 2                                  division by zero
# 3  invalid literal for int() with base 10: 'animal'
#
#                            traceback1  \
# 0  Traceback (most recent call last):
# 1  Traceback (most recent call last):
# 2  Traceback (most recent call last):
# 3  Traceback (most recent call last):
#
#                                           traceback2  \
# 0    File "C:\Users\tomon\Documents\Python\base_p...
# ...
